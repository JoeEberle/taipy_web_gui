# %% [markdown]
# ![taipy_web_gui.png](attachment:5e3a7913-3b8d-4013-b2db-03d40427ad00.png)

# %% [markdown]
# # Machine Learning with TAIPY Web GUI and Tensorflow Machine Learning
#
# ## Image Detection Neural Network
#
# #### by Joe Eberle started on 04-13-2024 - https://github.com/JoeEberle/ - josepheberle@outlook.com

# %% [markdown]
# ![solution_template.png](attachment:0c6d44fa-4549-4f29-824f-5b236e6d482e.png)

# %%
first_install = False 
if first_install:
    # !pip install taipy

# %%
import os
import schedule
from datetime import datetime
import pandas as pd 
import quick_logger as ql
import talking_code as tc 
import file_manager as fm 

import time
print(f"Libraries Imported succesfully on {datetime.now().date()} at {datetime.now().time()}")
# Out:
# Libraries Imported succesfully on 2024-04-07 at 21:53:51.939225

# %% [markdown]
# ## Optional Step 0 - Intitiate Configuration Settings and name the overall solution

# %%
import configparser 
config = configparser.ConfigParser()
cfg = config.read('config.ini')  

solution_name = 'taipy_web_gui'

# %% [markdown]
# ## Optional Step 0 - Intitiate Logging and debugging

# %%
# Establish the Python Logger  
import logging # built in python library that does not need to be installed 
import quick_logger as ql

global start_stime 
start_time = ql.set_start_time()
logging = ql.create_logger_start(solution_name, start_time) 
ql.set_speaking_log(False)
ql.set_speaking_steps(False)
ql.pvlog('info',f'Process {solution_name} Step 0 - Initializing and starting Logging Process.')
# Out:
# Process taipy_web_gui Step 0 - Initializing and starting Logging Process.

# %%
classifier_application = """
from taipy.gui import Gui

app = Gui()

if __name__ == "__main__":
    app.run(use_reloader=True) 
""" 
 

 
with open('classifier.py', 'w') as file:
    file.write(classifier_application)

# %% [markdown]
# ## Step 0 - Process End - display log

# %%
# Calculate and classify the process performance 
status = ql.calculate_process_performance(solution_name, start_time) 
print(ql.append_log_file(solution_name))

# %% [markdown]
# #### https://github.com/JoeEberle/ -- josepheberle@outlook.com
